# %%
import pandas as pd 
import seaborn as sns
from glob import glob
import numpy as np

# %% [markdown]
# ## BertScore

# %%
folder_name = 'eval_result_v1_IT'
folder_path = glob(f'./{folder_name}/*')
folder_paths = [glob(dir + '/*') for dir in folder_path]
file_paths = sum(folder_paths, [])
file_paths
print(file_paths)
df_list=[]
for file_path in file_paths:
    value = file_path.replace('.csv', '').split('+')
    model_name = '_'.join(value[-1].split('_')[:-1])
    cross_domain = model_name

    df=pd.read_csv(file_path)
    df['cross_domain'] = cross_domain
 
    df_list.append(df)
result_df = pd.concat(df_list)
result_df  = result_df.sort_values(by=['cross_domain', 'Model'], ignore_index=True)
result_df.to_csv(f'{folder_name}_bs.csv')

g = sns.catplot(data=result_df, kind='bar', x='cross_domain', y='BERT-S', hue='Model')
g.set_xticklabels(rotation=30)
# Out:
# ['./eval_result_v1_IT/facebook/bart-large+MT_DG_BS.csv', './eval_result_v1_IT/facebook/bart-large+MS_DG_BS.csv', './eval_result_v1_IT/facebook/blenderbot-3B+MS_DG_BS.csv', './eval_result_v1_IT/facebook/blenderbot-3B+MT_DG_BS.csv', './eval_result_v1_IT/meta-llama/Llama-2-13b-chat-hf+MT_DG_BS.csv', './eval_result_v1_IT/meta-llama/Llama-2-13b-chat-hf+MS_DG_BS.csv', './eval_result_v1_IT/jihyoung/rebot-generation+MS_DG_BS.csv', './eval_result_v1_IT/jihyoung/rebot-generation+MT_DG_BS.csv', './eval_result_v1_IT/lmsys/vicuna-13b-v1.5-16k+MT_DG_BS.csv', './eval_result_v1_IT/lmsys/vicuna-13b-v1.5-16k+MS_DG_BS.csv', './eval_result_v1_IT/mistralai/Mistral-7B-v0.1+MT_DG_BS.csv', './eval_result_v1_IT/mistralai/Mistral-7B-v0.1+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-small+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-large+MT_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-xxl+MT_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-base+MT_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-small+MT_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-large+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-base+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-xxl+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-xl+MS_DG_BS.csv', './eval_result_v1_IT/google/flan-t5-xl+MT_DG_BS.csv', './eval_result_v1_IT/openchat/openchat_3.5+MT_DG_BS.csv', './eval_result_v1_IT/openchat/openchat_3.5+MS_DG_BS.csv']
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
folder_name = 'eval_result_v2_other_encdec'
folder_path = glob(f'./{folder_name}/*')
folder_paths = [glob(dir + '/*') for dir in folder_path]
file_paths = sum(folder_paths, [])
file_paths
print(file_paths)
df_list=[]
for file_path in file_paths:
    value = file_path.replace('.csv', '').split('+')
    model_name = '_'.join(value[-1].split('_')[:-1])
    cross_domain = model_name

    df=pd.read_csv(file_path)
    df['cross_domain'] = cross_domain
 
    df_list.append(df)
result_df = pd.concat(df_list)
result_df  = result_df.sort_values(by=['cross_domain', 'Model'], ignore_index=True)
result_df.to_csv(f'{folder_name}.csv')

g = sns.catplot(data=result_df, kind='bar', x='cross_domain', y='ROUGE-L', hue='Model')
g.set_xticklabels(rotation=30)
# Out:
# ['./eval_result_v2_other_encdec/facebook/blenderbot-3B+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/facebook/bart-large+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/facebook/bart-large+MT_DG_BS.csv', './eval_result_v2_other_encdec/facebook/bart-large+MS_DG_BS.csv', './eval_result_v2_other_encdec/facebook/blenderbot-3B+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/facebook/bart-large+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/facebook/blenderbot-3B+MS_DG_BS.csv', './eval_result_v2_other_encdec/facebook/blenderbot-3B+MT_DG_BS.csv', './eval_result_v2_other_encdec/jihyoung/rebot-generation+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/jihyoung/rebot-generation+MS_DG_BS.csv', './eval_result_v2_other_encdec/jihyoung/rebot-generation+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/jihyoung/rebot-generation+MT_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-small+MS_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-large+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-large+MT_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xl+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xxl+MT_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-base+MT_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-small+MT_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-small+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-base+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xl+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-large+MS_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-base+MS_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-base+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xxl+MS_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xxl+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xl+MS_DG_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-large+MS_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xxl+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-small+MT_DG_SFT_BS.csv', './eval_result_v2_other_encdec/google/flan-t5-xl+MT_DG_BS.csv']

# %%
folder_name = 'eval_result_v3_dec'
folder_path = glob(f'./{folder_name}/*')
folder_paths = [glob(dir + '/*') for dir in folder_path]
file_paths = sum(folder_paths, [])
file_paths
print(file_paths)
df_list=[]
for file_path in file_paths:
    value = file_path.replace('.csv', '').split('+')
    model_name = '_'.join(value[-1].split('_')[:-1])
    cross_domain = model_name

    df=pd.read_csv(file_path)
    df['cross_domain'] = cross_domain
 
    df_list.append(df)
result_df = pd.concat(df_list)
result_df  = result_df.sort_values(by=['cross_domain', 'Model'], ignore_index=True)
result_df.to_csv(f'{folder_name}.csv')

g = sns.catplot(data=result_df, kind='bar', x='cross_domain', y='BERT-S', hue='Model')
g.set_xticklabels(rotation=30)
# Out:
# ['./eval_result_v3_dec/meta-llama/Llama-2-7b-chat-hf+MS_DG_SFT_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-7b-chat-hf+MT_DG_SFT_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-7b-chat-hf+MS_DG_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-13b-chat-hf+MT_DG_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-13b-chat-hf+MT_DG_SFT_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-13b-chat-hf+MS_DG_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-13b-chat-hf+MS_DG_SFT_BS.csv', './eval_result_v3_dec/meta-llama/Llama-2-7b-chat-hf+MT_DG_BS.csv', './eval_result_v3_dec/pinkmanlove/llama-13b-hf+MS_DG_SFT_BS.csv', './eval_result_v3_dec/pinkmanlove/llama-13b-hf+MT_DG_SFT_BS.csv', './eval_result_v3_dec/pinkmanlove/llama-13b-hf+MT_DG_BS.csv', './eval_result_v3_dec/pinkmanlove/llama-13b-hf+MS_DG_BS.csv', './eval_result_v3_dec/lmsys/vicuna-13b-v1.5-16k+MT_DG_BS.csv', './eval_result_v3_dec/lmsys/vicuna-13b-v1.5-16k+MS_DG_BS.csv', './eval_result_v3_dec/lmsys/vicuna-13b-v1.5-16k+MS_DG_SFT_BS.csv', './eval_result_v3_dec/lmsys/vicuna-13b-v1.5-16k+MT_DG_SFT_BS.csv', './eval_result_v3_dec/mistralai/Mistral-7B-v0.1+MS_DG_SFT_BS.csv', './eval_result_v3_dec/mistralai/Mistral-7B-v0.1+MT_DG_SFT_BS.csv', './eval_result_v3_dec/mistralai/Mistral-7B-v0.1+MT_DG_BS.csv', './eval_result_v3_dec/mistralai/Mistral-7B-v0.1+MS_DG_BS.csv', './eval_result_v3_dec/openchat/openchat_3.5+MT_DG_BS.csv', './eval_result_v3_dec/openchat/openchat_3.5+MS_DG_BS.csv', './eval_result_v3_dec/openchat/openchat_3.5+MT_DG_SFT_BS.csv', './eval_result_v3_dec/openchat/openchat_3.5+MS_DG_SFT_BS.csv']

# %%
folder_name = 'eval_result_v2_other_dec'
folder_path = glob(f'./{folder_name}/*')
folder_paths = [glob(dir + '/*') for dir in folder_path]
file_paths = sum(folder_paths, [])
file_paths
print(file_paths)
df_list=[]
for file_path in file_paths:
    value = file_path.replace('.csv', '').split('+')
    model_name = '_'.join(value[-1].split('_')[:-1])
    cross_domain = model_name

    df=pd.read_csv(file_path)
    df['cross_domain'] = cross_domain
 
    df_list.append(df)
result_df = pd.concat(df_list)
result_df  = result_df.sort_values(by=['cross_domain', 'Model'], ignore_index=True)
result_df.to_csv(f'{folder_name}.csv')

g = sns.catplot(data=result_df, kind='bar', x='cross_domain', y='BERT-S', hue='Model')
g.set_xticklabels(rotation=30)
# Out:
# ['./eval_result_v2_other_dec/meta-llama/Llama-2-7b-chat-hf+MS_DG_SFT_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-7b-chat-hf+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-7b-chat-hf+MS_DG_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-13b-chat-hf+MT_DG_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-13b-chat-hf+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-13b-chat-hf+MS_DG_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-13b-chat-hf+MS_DG_SFT_BS.csv', './eval_result_v2_other_dec/meta-llama/Llama-2-7b-chat-hf+MT_DG_BS.csv', './eval_result_v2_other_dec/pinkmanlove/llama-13b-hf+MS_DG_SFT_BS.csv', './eval_result_v2_other_dec/pinkmanlove/llama-13b-hf+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/pinkmanlove/llama-13b-hf+MT_DG_BS.csv', './eval_result_v2_other_dec/pinkmanlove/llama-13b-hf+MS_DG_BS.csv', './eval_result_v2_other_dec/lmsys/vicuna-13b-v1.5-16k+MT_DG_BS.csv', './eval_result_v2_other_dec/lmsys/vicuna-13b-v1.5-16k+MS_DG_BS.csv', './eval_result_v2_other_dec/lmsys/vicuna-13b-v1.5-16k+MS_DG_SFT_BS.csv', './eval_result_v2_other_dec/lmsys/vicuna-13b-v1.5-16k+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/mistralai/Mistral-7B-v0.1+MS_DG_SFT_BS.csv', './eval_result_v2_other_dec/mistralai/Mistral-7B-v0.1+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/mistralai/Mistral-7B-v0.1+MT_DG_BS.csv', './eval_result_v2_other_dec/mistralai/Mistral-7B-v0.1+MS_DG_BS.csv', './eval_result_v2_other_dec/openchat/openchat_3.5+MT_DG_BS.csv', './eval_result_v2_other_dec/openchat/openchat_3.5+MS_DG_BS.csv', './eval_result_v2_other_dec/openchat/openchat_3.5+MT_DG_SFT_BS.csv', './eval_result_v2_other_dec/openchat/openchat_3.5+MS_DG_SFT_BS.csv']

# %% [markdown]
# ## GPT Score

# %%
# file_path = './eval_result_reason-v3-fixedprompt-match'
# file_path = './eval_result_reason-v3-fixedprompt-match-2'
# file_path = './eval_result_reason-v3-fixedprompt-match-3'

# file_path = './eval_result_reason-v3-fixedprompt-json'
# file_path = './eval_result_reason-v3-fixedprompt-json-'
file_path = './eval_result_reason-v3-fixedprompt-json-3'

result_list = glob(file_path + '/*.csv')
result_list.sort()

gptscore_result = []
for result in result_list:
    value = result.replace('.csv', '').split('+')
    model_name = '_'.join(value[:-1]).split('/')[-1]
    cross_domain = value[-1]
    
    df = pd.read_csv(result)
    score = df['rating'].mean()
    
    gptscore_result.append({'model':model_name, 'cross_domain':cross_domain, 'GPTScore':round(score,2)})

score_df = pd.DataFrame(gptscore_result)
score_df = score_df.sort_values(by=['cross_domain', ], ignore_index=True)
score_df
# Out:
#             model cross_domain  GPTScore
# 0    llama-7b_MS2        MS_DG      6.90
# 1  llama-7b_MS_DG        MS_DG      6.55
# 2    llama-7b_MT2        MS_DG      7.35
# 3  llama-7b_MT_DG        MS_DG      6.00
# 4    llama-7b_MS2        MT_DG      6.05
# 5  llama-7b_MS_DG        MT_DG      5.00
# 6    llama-7b_MT2        MT_DG      6.15
# 7  llama-7b_MT_DG        MT_DG      5.10

# %%
score_df['GPTScore'].tolist()
# Out:
# [6.9, 6.55, 7.35, 6.0, 6.05, 5.0, 6.15, 5.1]

# %% [markdown]
# ##  Significant Difference

# %%
# data = [[6.43, 6.0, 6.89, 5.33, 7.0, 6.08, 6.73, 5.58],
#         [6.55, 6.33, 7.38, 5.09, 6.67, 6.08, 6.8, 6.06],
#         [8.38, 5.86, 7.5, 6.44, 6.92, 6.07, 7.0, 6.14]
# ]
data = [[6.45, 6.55, 6.55, 6.45, 5.89, 5.35, 6.37, 5.0],
        [6.79, 6.15, 7.15, 6.55, 6.37, 5.35, 6.3, 5.26],
        [6.9, 6.55, 7.35, 6.0, 6.05, 5.0, 6.15, 5.1]
]
data = np.array(data).transpose()
data
# Out:
# array([[6.45, 6.79, 6.9 ],
#        [6.55, 6.15, 6.55],
#        [6.55, 7.15, 7.35],
#        [6.45, 6.55, 6.  ],
#        [5.89, 6.37, 6.05],
#        [5.35, 5.35, 5.  ],
#        [6.37, 6.3 , 6.15],
#        [5.  , 5.26, 5.1 ]])

# %%
import scipy.stats

def anova_test(*groups):
    f_statistic, p_value = scipy.stats.f_oneway(*groups)
    
    return p_value

# 예시 데이터 (세 개의 그룹)
group1 = [25, 30, 35, 40, 45]
group2 = [20, 28, 32, 38, 42]
group3 = [15, 25, 30, 35, 40]

# ANOVA 검정
# result_pvalue = anova_test(group1, group2, group3)
result_pvalue = anova_test(data[0], data[1])

print("P-value:", result_pvalue)

# p-value가 0.05 이하인 경우, 적어도 하나의 그룹 간에는 통계적으로 유의미한 차이가 있다고 간주할 수 있습니다.
if result_pvalue < 0.05:
    print("적어도 하나의 그룹 간에는 통계적으로 유의미한 차이가 있습니다.")
else:
    print("그룹 간에는 통계적으로 유의미한 차이가 없습니다.")
# Out:
# P-value: 0.193563616824515
# 그룹 간에는 통계적으로 유의미한 차이가 없습니다.

# %%
df= pd.read_csv('/home/uj-user/Yo/hybrid-ltm/data/eval_result/llama-7b+BS.csv')
df
# Out:
#    cross           Model   ROUGE  BertScore
# 0  MS_DG  llama-7b_MT_DG  0.2988     0.6806
# 1  MS_DG    llama-7b_MT2  0.3140     0.6886
# 2  MS_DG  llama-7b_MS_DG  0.3133     0.6929
# 3  MS_DG    llama-7b_MS2  0.3143     0.6837
# 4  MT_DG  llama-7b_MT_DG  0.3205     0.6946
# 5  MT_DG    llama-7b_MT2  0.3577     0.7073
# 6  MT_DG  llama-7b_MS_DG  0.3105     0.6887
# 7  MT_DG    llama-7b_MS2  0.3150     0.6785

# %%
df1 = pd.read_csv('/home/uj-user/Yo/hybrid-ltm/data/eval_result/llama-7b+MT_DG_BS_bak.csv')
df2 = pd.read_csv('/home/uj-user/Yo/hybrid-ltm/data/eval_result/llama-7b+MT_DG_BS.csv')
df1 = df1.drop(columns=['Model'])
df2 = df2.drop(columns=['Model'])
df2
# Out:
#     ROUGE  BertScore
# 0  0.3205     0.6946
# 1  0.3577     0.7073
# 2  0.3105     0.6887
# 3  0.3150     0.6785

# %%
import pandas as pd
from scipy.stats import ttest_ind

# 예제 데이터프레임 생성
# data1 = {'A': [6.43, 6.0, 6.89, 5.33, 7.0, 6.08, 6.73, 5.58]}
# data1 = {'A': [6.54, 6.32, 7.35, 5.08, 6.68, 6.08, 6.8, 6.06]}

# data2 = {'A': [6.55, 6.33, 7.38, 5.09, 6.67, 6.08, 6.8, 6.06]}

# df1 = pd.DataFrame(data1)
# df2 = pd.DataFrame(data2)

# 열마다 t-검정 수행
for column in df1.columns:
    t_statistic, p_value = ttest_ind(df1[column], df2[column])
    print(f'Test for column {column}:')
    print(f'T-statistic: {t_statistic}')
    print(f'P-value: {p_value}')

    # P-value가 유의수준(예: 0.05)보다 작으면 귀무가설 기각
    if p_value < 0.05:
        print(f'Reject the null hypothesis for column {column}: There is a significant difference.')
    else:
        print(f'Fail to reject the null hypothesis for column {column}: There is no significant difference.')

    print('\n')
# Out:
# Test for column ROUGE:
# T-statistic: -0.6751512587223705
# P-value: 0.5186131635861952
# Fail to reject the null hypothesis for column ROUGE: There is no significant difference.
#
#
# Test for column BertScore:
# T-statistic: -0.7241738477785662
# P-value: 0.4895922212199193
# Fail to reject the null hypothesis for column BertScore: There is no significant difference.
